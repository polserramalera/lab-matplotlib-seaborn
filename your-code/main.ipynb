# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import math

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1
Fig, ax= plt.subplots(figsize=(15,5))
# we add a title to the figure or the ax
ax.set_title("Challenge 1 plot",fontsize=18)
# we plot the different lines
ax.plot(x,y,label="y=x*2",c="red")
ax.plot(x,z,label="y=x**2",c="green")
Fig.legend()

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
x1 = np.arange(0,100)
y1 = x*2
z1 = x**2

# %%
# 1 row 2 columns
Fig1, axes1= plt.subplots(1,2,figsize=(15,5))
# we add a title to the figure or the ax
Fig1.suptitle("Challenge 1 plot",fontsize=18)
# we plot the different lines
axes1[0].plot(x1,y1,color="red",label="y=x*2")
axes1[0].set_title("Y axe")
axes1[1].plot(x1,z1,color="green",label="y=x**2")
axes1[1].set_title("Z axe")
Fig1.legend()

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
# your code here
# 1 row 2 columns
Fig1, axes1= plt.subplots(1,2,figsize=(6,6))
# we add a title to the figure or the ax
Fig1.suptitle("Challenge 1 plot",fontsize=18)
# we plot the different lines
axes1[0].plot(x1,y1,color="red",label="y=x*2")
axes1[0].set_title("Y axe")
axes1[1].plot(x1,z1,color="green",label="y=x**2")
axes1[1].set_title("Z axe")
Fig1.legend()

# %% [markdown]
# #### Now you will have to plot both $y=x^2$ and $y=e^x$ in the same plot. Create two subplots and use a normal scale in the first one and a logarithmic scale in the second one.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
# your code here
y2=x**2
y3=math.e**x
Fig2,axes2=plt.subplots(1,2,figsize=(15,10))
axes2[0].plot(y2,y3,color="green")
axes2[0].set_xscale("linear")
axes2[1].plot(y2,y3,color="green")
axes2[1].set_xscale("log")

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here
y2=x**2
y3=math.e**x
Fig2,axes2=plt.subplots(1,2,figsize=(15,10))
axes2[0].plot(y2,y3,color="green",label="linear")
axes2[0].set_xscale("linear")
axes2[1].plot(y2,y3,color="blue",label="log")
axes2[1].set_xscale("log")
Fig2.legend()

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
fitbit=pd.read_csv("../datasets/Fitbit2.csv")
fitbit.head()
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  ...  Distance_miles      Days  Days_encoded  \
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# MEDIAN STEPS BY MONTH_ENCODED
# your code here
fit_months = fitbit.groupby("Months_encoded")["Steps"].median()
fit_months
# Out:
# Months_encoded
# 1     10366.0
# 2      9235.0
# 3     11122.0
# 4     13846.5
# 5     11998.0
# 6     12935.5
# 7     10644.0
# 8     12213.0
# 9      9343.0
# 10     7865.0
# 11     9453.5
# 12     8531.0
# Name: Steps, dtype: float64

# %%
# MEDIAN STEPS BY WORK_OR_WEEKEND
# your code here
fit_weekend = fitbit.groupby("Work_or_Weekend")["Steps"].median()
fit_weekend
fitbit[fitbit["Work_or_Weekend"] == 0].groupby(fitbit['Days'])['Steps'].count()

fitbit[fitbit["Work_or_Weekend"] == 0].groupby(fitbit['Days'])['Steps'].count()
fitbit["Steps"].groupby(fitbit["Work_or_Weekend"]).median()
# Out:
# Work_or_Weekend
# 0     9998.0
# 1    10445.5
# Name: Steps, dtype: float64

# %%
plt.style.use('classic')
Fig3,axes3=plt.subplots(1,2,figsize=(12,4))
Fig3.suptitle("Challenge 2",fontsize=18)

axes3[0].plot(fit_months.index,fit_months,color="green",label="Month")
axes3[0].set_title("Months")
plt.sca(axes3[0])
plt.xticks(list(range(13)), ["","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"], rotation = 'horizontal')


axes3[1].bar(fit_weekend.index,fit_weekend,color="blue",label="Weekend")
axes3[1].set_title("Weekend")
plt.sca(axes3[1])
plt.xticks(range(2), ["Weekend","Workdays"], rotation = 'horizontal')
plt.show

# %%
fig1.savefig("../figures/challenge2.png")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-9f44c8bbf1d9> in <module>
# ----> 1 fig1.savefig("../figures/challenge2.png")
#
# AttributeError: 'function' object has no attribute 'savefig'

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
columns=["Minutes Lightly Active","Minutes Very Active","Minutes Sedentary"]
i=0

Fig4,axes4=plt.subplots(1,len(columns),figsize=(16,8))
Fig4.suptitle("Challenge 2 loop",fontsize=18)

for col in columns: 
    axes4[i].scatter(col,"Steps",data=fitbit,color="green")
    axes4[i].set_title(col)
    i+=1

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here
titanic=pd.read_csv("../datasets/titanic.csv")
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here
pd.DataFrame(titanic)
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name  Gender        Age  \
# 0                               Braund, Mr. Owen Harris    male  22.000000
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                                Heikkinen, Miss. Laina  female  26.000000
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                              Allen, Mr. William Henry    male  35.000000
# ...

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here
titanic.select_dtypes("number")
# Out:
#       PassengerId  Survived  Pclass        Age  SibSp  Parch      Fare
# 0               1       0.0       3  22.000000      1      0    7.2500
# 1               2       1.0       1  38.000000      1      0   71.2833
# 2               3       1.0       3  26.000000      0      0    7.9250
# 3               4       1.0       1  35.000000      1      0   53.1000
# 4               5       0.0       3  35.000000      0      0    8.0500
# ...           ...       ...     ...        ...    ...    ...       ...
# 1304         1305       NaN       3  29.513190      0      0    8.0500
# 1305         1306       NaN       1  39.000000      0      0  108.9000
# 1306         1307       NaN       3  38.500000      0      0    7.2500
# 1307         1308       NaN       3  29.513190      0      0    8.0500
# 1308         1309       NaN       3  25.315435      1      1   22.3583
#
# [1309 rows x 7 columns]

# %%
# CATEGORICAL VARIABLES
# your code here
titanic.select_dtypes("object")
# Out:
#                                                    Name  Gender  \
# 0                               Braund, Mr. Owen Harris    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss. Laina  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                              Allen, Mr. William Henry    male
# ...                                                 ...     ...
# 1304                                 Spector, Mr. Woolf    male
# 1305                       Oliva y Ocana, Dona. Fermina  female
# 1306                       Saether, Mr. Simon Sivertsen    male
# 1307                                Ware, Mr. Frederick    male
# 1308                           Peter, Master. Michael J    male
#
#                   Ticket Cabin Embarked
# 0              A/5 21171    U0        S
# 1               PC 17599   C85        C
# 2       STON/O2. 3101282    U0        S
# ...

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here
plt.style.use('classic')
plt.figsize=(12,6)

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here
Fig5,axes5=plt.subplots()
Fig5.suptitle("Challenge 3",fontsize=18)
axes5.hist("Age", data=titanic)
axes5.set_title("Age distribution")
# Out:
# Text(0.5, 1.0, 'Age distribution')

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here
Fig6,axes6=plt.subplots(1,3,figsize=(16,8))
Fig6.suptitle("Challenge 3",fontsize=18)
axes6[0].hist("Age",data=titanic,bins=10)
axes6[0].set_title("Bin 10")
axes6[1].hist("Age",data=titanic,bins=20)
axes6[1].set_title("Bin 20")
axes6[2].hist("Age",data=titanic,bins=50)
axes6[2].set_title("Bin 50")
# Out:
# Text(0.5, 1.0, 'Bin 50')

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
With more bins there is more precision distributing the data
"""

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here
sns.distplot(titanic["Age"],kde=False)

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
fig7, ax7 = plt.subplots(figsize=(12,6))
ax7.bar(x=titanic["Gender"].value_counts().index, height=titanic["Gender"].value_counts(), color=("slateblue", "seagreen"))
# Out:
# <BarContainer object of 2 artists>

# %%
# Method 2 - seaborn
# your code here
sns.barplot(x=titanic["Gender"].value_counts().index, y=titanic["Gender"].value_counts())

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# Out:
# 3    709
# 1    323
# 2    277
# Name: Pclass, dtype: int64

# %%
# your code here

fig8, ax8 = plt.subplots(figsize=(10,8))
ax8.bar(x=titanic["Pclass"].value_counts().index, height= titanic["Pclass"].value_counts(),data=titanic)
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
sns.catplot(data=titanic, y="Age", kind="box")

# %%
"""
your comments here
"""

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
your comments here
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
sns.catplot(data=titanic, y="Age", kind="violin")

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
fig9, ax9 = plt.subplots(figsize=(12,8))
ax9.scatter(titanic["Age"], titanic["Fare"])

# %%
# Method 2 - seaborn
# your code here
sns.regplot(data=titanic, x="Age", y="Fare")

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here
sns.heatmap(titanic.corr())

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
your comments here
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here
sns.catplot(data=titanic, y="Age", col="Pclass", kind="box")

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here
sns.FacetGrid(data=titanic, hue="Gender", height=10).map(plt.hist, "Age").add_legend()
